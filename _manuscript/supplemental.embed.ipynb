# %% [markdown]
# # Supplemental Materials
#
# Rachel Rapier
# July 8, 2026
#
# # Supplemental Materials
#
# Add supplemental materials here.

# %% [raw]
# <!-- -->

# %% [markdown]
# ``` markdown
# ---
# title: "Supplemental Materials"
# author: "Rachel Rapier"
# date: "July 8, 2026"
# ---
#
# # Supplemental Materials
#
# Add supplemental materials here.
# ```
